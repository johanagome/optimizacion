# %% [markdown]
# # Actividad imagen satélital: Dividir calles de pasto.

# %% [markdown]
# - **Autor:** Johana Gómez Ceballos
# - **Fecha:** 08/05/18
# - **Asignatura:** Optimización

# %% [markdown]
# El presente trabajo comprende el analisis y procesamiento de una imagen en este caso satelital con el objetivo de separar calles de pasto utilizando scikit-image de python  a traves de la libreria skimage,el cual  es una colección de algoritmos para el procesamiento de imágenes y está disponible de forma gratuita y sin restricciones,ademas su instalacion es relativamente facil  solo se debe abrir la consola de comandos cmd y ejecutar esta linea.
#
# >>pip install -U scikit-image

# %% [markdown]
# ###  Importar la imagen satélital

# %% [markdown]
# Se selecciona una imagen en este se denomina "Imagen3.png" la cual debe estar en la misma carpeta donde se encuentra el codigo para poder ser importada, luego se utiliza el módulo io de scikit-image el cual permite leer y pyplot de matplotlib que se encarga de mostrar la imagen, a continuación se muestra como se hace lo anterior mensionado en codigo python.

# %%
from skimage import io,color
import matplotlib.pyplot as plt

# %% [markdown]
# Ahora se utiliza  la función imread del módulo io para leer la imagen, y se guarda esto en una variable, en la cual se almacenará un array de NumPy con la información de los colores que componen la imagen.

# %%
imagen =io.imread('Imagen3.png')

# %% [markdown]
# Enseguida utilizamos la función imshow para mostrar la imagen  y la función show para mostrar toda la ventana o figure que contiene la(s) imágenes a desplegar en la pantalla.

# %%
plt.imshow(imagen)
plt.show()

# %% [markdown]
# Juntando este pequeño codigo quedaria asi:

# %% [markdown]
# Si ejecutamos todo lo anterior junto nos mostrará la imagen leída en una ventana o figure de Matplotlib, tal como se aprecia en la siguiente imagen

# %%
from skimage import io,color
import matplotlib.pyplot as plt
imagen =io.imread('Imagen3.png')
plt.imshow(imagen)
plt.show()

# %% [markdown]
# luego se averigua la forma o cantidad de elementos del array imagen utilizando el método shape y con ello nos mostrará en consola una tupla de 3 elementos con la información del número de filas, columnas y capas de la matriz entonces añadiendo  lo siguiente en el script anterior obtendremos las dimensiones de la imagen:

# %%
print (imagen.shape)
# Out:
# (584, 1261, 4)

# %% [markdown]
# Lo cual implica que tenemos una imagen de 584x1261 pixeles. El tercer número indica que tenemos 4 capas o canales del módelo de color RGB.

# %% [markdown]
# ### Imagen en escala de grises

# %% [markdown]
# Ahora se convierte la matriz de color que se tiene en una matriz en tono de grises  importando  el módulo color y utilizando la función rgb2gray:

# %%
from skimage import color
import matplotlib.pyplot as plt
imagengris = color.rgb2gray(imagen)
plt.imshow(imagengris, cmap='gray')
plt.show()

# %% [markdown]
# ### Codigo

# %%
from skimage import io,color
import matplotlib.pyplot as plt
imagen =io.imread('Imagen3.png')
imagen1 =io.imread('Imagen3.png')
imagengris = color.rgb2gray(imagen)
imageng = color.rgb2gray(imagen)
print (imagen.shape)
imagenca=imagengris
# Out:
# (584, 1261, 4)

# %% [markdown]
#  En la escala de grises la imagen se encuentra  aproximadamente entre de 0.27 y 0.38 ,lo que se necesita hacer es recorrer la imagen totalmente y realizar un analisis de la imagen gris para asi realizar las modificaciones correspondientes en la imagen original y poder separar calles de pasto,para esto se utilizan dos for que realizaran todo lo anteriormente mencionado.

# %%
for i in range(568):
    for j in range(1218):
        if imagenca[i][j]<=0.38  and imagenca[i][j]>=0.27:
            imagenca[i][j]=0
        else:
            imagenca[i][j]=1

# %% [markdown]
# por ultimo,se grafican las imagenes obtenidas usando comandos de las librerias skimage y matplolib.

# %%
plt.subplot(221)
plt.imshow(imagen2, cmap='gray')
plt.title('Calles')
plt.subplot(222)
plt.imshow(imagen)
plt.title('Pasto y casas')
plt.subplot(223)
plt.imshow(imagen3, cmap='gray')
plt.title('Imagen en gris')
plt.show()

# %%
#johana gomez ceballos
from skimage import io,color
import matplotlib.pyplot as plt
imagen =io.imread('Imagen3.png')
imagen1 =io.imread('Imagen3.png')
imagengris = color.rgb2gray(imagen)
imageng = color.rgb2gray(imagen)
imagengc = color.rgb2gray(imagen)
plt.title('Imagen original')
print (imagen.shape)
imagenca=imagengris
for i in range(568):
    for j in range(1218):
        if imagenca[i][j]<=0.38  and imagenca[i][j]>=0.27:
            imagenca[i][j]=0
            imagengc[i][j]=1
        else:
            imagenca[i][j]=1
            imagengc[i][j]=0

plt.subplot(221)
plt.imshow(imagenca, cmap='gray')
plt.title('Pastos')
plt.subplot(222)
plt.imshow(imagen)
plt.title('Pasto y Casas')
plt.subplot(223)
plt.imshow(imageng, cmap='gray')
plt.title('Imagen en gris')
plt.subplot(224)
plt.imshow(imagengc, cmap='gray')
plt.title('Calles')
plt.show()
# Out:
# (584, 1261, 4)
